# %%
# !python -m pip install Pillow

# %%
from PIL import Image

# %%
pil_im = Image.open('landscape.jpeg')

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250>

# %%
type(pil_im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
print(pil_im.size)
# Out:
# (500, 250)

# %%
out = pil_im.resize((50,50))

# %%
out
# Out:
# <PIL.Image.Image image mode=RGB size=50x50>

# %%
pil_im = Image.open('landscape.jpeg')

# %%
pil_im.convert('L')
# Out:
# <PIL.Image.Image image mode=L size=500x250>

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x250>

# %%
pil_im.thumbnail((50,50))

# %%
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=50x25>

# %%
pil_im = Image.open('landscape.jpeg')

# %%
box = (100,100,400,400)
region = pil_im.crop(box)

# %%
region
# Out:
# <PIL.Image.Image image mode=RGB size=300x300>

# %%
im = pil_im.rotate(45)
im
# Out:
# <PIL.Image.Image image mode=RGB size=500x250>

# %%
im.save('flower1.jpg')

# %%
from pylab import *

# %%
# read image to array
im = array(Image.open('landscape.jpeg'))
# plot the image
imshow(im)
# some points
x = [100,100,40,60]
y = [20,100,60,40]
# plot the points with red star-markers
#plot(x,y) # default blue solid line
#plot(x,y,'r*') # red star-markers
#plot(x,y,'go-') # green line with circle-markers
plot(x,y,'ks:') # black dotted line with square-markers
# line plot connecting the first two points
plot(x[:2],y[:2],'g+:')
# add title and show the plot
title('Plotting: "landscape.jpeg"')
axis('off')
show()

# %%
# read image to array
im = array(Image.open('landscape.jpeg'))
# plot the image
imshow(im)
# some points
x = [100,100,40,60]
y = [20,100,60,40]
# plot the points with red star-markers
plot(x,y,'go')
# line plot connecting the first two points
plot(x[:2],y[:2])
# add title and show the plot
title('Plotting: "landscape.jpeg"')
show()

# %%
#OpenCV Library
# !pip install opencv-python

# %%
import cv2

# %%
img = cv2.imread("landscape.jpeg", cv2.IMREAD_COLOR) #cv2.IMREAD_COLOR or 1

# %%
cv2.imshow("image", img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (250, 500, 3)

# %%
img.size
# Out:
# 375000

# %%
#Accessing and Modify Pixels 
px1 = img[100,100]
print(px1)
# Out:
# [40 53 85]

# %%
px2 = img[100,100,0]
print(px2)
# Out:
# 40

# %%
px3 = img[100,100,1]
print(px3)
# Out:
# 53

# %%
px4 = img[100,100,2]
print(px4)
# Out:
# 85

# %%
img[100,100] = [255,255,255]
print(img[100,100])
# Out:
# [255 255 255]

# %%
img[:100,:100, ] = [255,255,255]
cv2.imshow("image", img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
img.item(100,100,2)
# Out:
# 255

# %%
img.itemset((100,100,2),68)
img.item(100,100,2)
# Out:
# 68

# %%
cv2.imshow("image", img)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (250, 500, 3)

# %%
img.size
# Out:
# 375000

# %%
img.dtype
# Out:
# dtype('uint8')

# %%
import numpy as np
import matplotlib.pyplot as plt
img=cv2.imread("landscape.jpeg")
#Displaying image using plt.imshow() method
plt.imshow(img)

# %%
# Converting BGR color to RGB color format
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
 
#Displaying image using plt.imshow() method
plt.imshow(RGB_img)

# %%
#Opening Image in GrayScale Mode
img = cv2.imread("landscape.jpeg", 0) #cv2.IMREAD_GRAYSCALE or 0

# %%
# Displaying the image
cv2.imshow('image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (250, 500)

# %%
cv2.imwrite('flower2.jpg', img)
# Out:
# True

# %%
img = cv2.imread("landscape.jpeg", 1) 
B, G, R = cv2.split(img)
# Corresponding channels are separated
 
cv2.imshow("original", img)
cv2.waitKey(0)
 
cv2.imshow("blue", B)
cv2.waitKey(0)
 
cv2.imshow("Green", G)
cv2.waitKey(0)
 
cv2.imshow("red", R)
cv2.waitKey(0)
 
cv2.destroyAllWindows()

# %%
B = img[:,:,0]
G = img[:,:,1]
R = img[:,:,2]
img[:,:,2]=0
cv2.imshow("newimage", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img = cv2.merge((B,G,R))
cv2.imshow("mergedimage", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
 
image = cv2.imread("landscape.jpeg", 1)
# Loading the image
 
half = cv2.resize(image, (0, 0), fx = 0.1, fy = 0.1)
bigger = cv2.resize(image, (1050, 1610))
 
stretch_near = cv2.resize(image, (780, 540),
               interpolation = cv2.INTER_NEAREST)
 
 
Titles =["Original", "Half", "Bigger", "Interpolation Nearest"]
images =[image, half, bigger, stretch_near]
count = 4
 
for i in range(count):
    plt.subplot(2, 2, i + 1)
    plt.title(Titles[i])
    plt.imshow(images[i])
 
plt.show()

# %%
#rotate image
rotate_90 = cv2.rotate(img, cv2.ROTATE_90_CLOCKWISE) 
cv2.imshow("image", rotate_90)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
rotate_90_counter = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE) 
cv2.imshow("image", rotate_90_counter)
cv2.waitKey(10000)
cv2.destroyAllWindows()

# %%
rotate_180 = cv2.rotate(img, cv2.ROTATE_180)
cv2.imshow("image", rotate_180)
cv2.waitKey(10000)
cv2.destroyAllWindows()
